# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Telecom_customer = pd.read_excel('Telekom müşteri.xlsx')
Telecom_customer
# Out:
#               ID Cinsiyet  Yaşlı Ortaklık Bağlılık  Kiralama süresi  \
# 0     7590-VHVEG   Female  Hayır     Evet    Hayır                1
# 1     5575-GNVDE     Male  Hayır    Hayır    Hayır               34
# 2     3668-QPYBK     Male  Hayır    Hayır    Hayır                2
# 3     7795-CFOCW     Male  Hayır    Hayır    Hayır               45
# 4     9237-HQITU   Female  Hayır    Hayır    Hayır                2
# ...          ...      ...    ...      ...      ...              ...
# 7038  6840-RESVB     Male  Hayır     Evet     Evet               24
# 7039  2234-XADUH   Female  Hayır     Evet     Evet               72
# 7040  4801-JZAZL   Female  Hayır     Evet     Evet               11
# 7041  8361-LTMKD     Male   Evet     Evet    Hayır                4
# 7042  3186-AJIEK     Male  Hayır    Hayır    Hayır               66
#
#      Telefon Servisi Çoklu Hat İnternet Servisi Online Güvenlik  ...  \
# 0              Hayır     Hayır              DSL           Hayır  ...
# ...

# %%
Telecom_customer.head()
# Out:
#   Cinsiyet  Yaşlı Ortaklık Bağlılık  Kiralama süresi Telefon Servisi  \
# 0   Female  Hayır     Evet    Hayır                1           Hayır
# 1     Male  Hayır    Hayır    Hayır               34            Evet
# 2     Male  Hayır    Hayır    Hayır                2            Evet
# 3     Male  Hayır    Hayır    Hayır               45           Hayır
# 4   Female  Hayır    Hayır    Hayır                2            Evet
#
#   Çoklu Hat İnternet Servisi Online Güvenlik Online Yedekleme Cihaz Koruması  \
# 0     Hayır              DSL           Hayır             Evet          Hayır
# 1     Hayır              DSL            Evet            Hayır           Evet
# 2     Hayır              DSL            Evet             Evet          Hayır
# 3     Hayır              DSL            Evet            Hayır           Evet
# 4     Hayır      Fiber optic           Hayır            Hayır          Hayır
#
#   Teknik Destek TV yayını  Film yayını    Sözleşme E-fatura  \
# ...

# %%
Telecom_customer.drop('ID', axis=1, inplace=True)

# %%
Telecom_customer["Ayrılma"]= Telecom_customer["Ayrılma"].replace("Hayır","Ayrılma olmadı") 
Telecom_customer["Ayrılma"]=Telecom_customer["Ayrılma"].replace("Evet","Ayrıkma olmadı")

# %%
Telecom_customer["Yaşlı"]=Telecom_customer["Yaşlı"].replace(0, "Hayır") 
Telecom_customer["Yaşlı"]=Telecom_customer["Yaşlı"].replace(1, "Evet")

# %%
Telecom_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cinsiyet          7043 non-null   object
#  1   Yaşlı             7043 non-null   object
#  2   Ortaklık          7043 non-null   object
#  3   Bağlılık          7043 non-null   object
#  4   Kiralama süresi   7043 non-null   int64
#  5   Telefon Servisi   7043 non-null   object
#  6   Çoklu Hat         7043 non-null   object
#  7   İnternet Servisi  7043 non-null   object
#  8   Online Güvenlik   7043 non-null   object
#  9   Online Yedekleme  7043 non-null   object
#  10  Cihaz Koruması    7043 non-null   object
#  11  Teknik Destek     7043 non-null   object
#  12  TV yayını         7043 non-null   object
#  13  Film yayını       7043 non-null   object
#  14  Sözleşme          7043 non-null   object
#  15  E-fatura          7043 non-null   object
# ...

# %%
Telecom_customer['Total Ödeme'] = pd.to_numeric(Telecom_customer['Total Ödeme'], errors='coerce')
Telecom_customer['Total Ödeme'] =Telecom_customer['Total Ödeme'].fillna(value=0)

# %%
Telecom_customer['Yaşlı'] = Telecom_customer['Yaşlı'].astype('object')

# %%
Telecom_customer.describe()
# Out:
#        Kiralama süresi  Aylık Fiyat  Total Ödeme
# count      7043.000000  7043.000000  7043.000000
# mean         32.370865    64.761692  2279.734304
# std          24.559231    30.090047  2266.794470
# min           0.000000    18.250000     0.000000
# 25%           9.000000    35.500000   398.550000
# 50%          29.000000    70.350000  1394.550000
# 75%          55.000000    89.850000  3786.600000
# max          72.000000   118.750000  8684.800000

# %%
Telecom_customer.corr()
# Out:
#                  Kiralama süresi  Aylık Fiyat  Total Ödeme
# Kiralama süresi         1.000000     0.247890     0.826172
# Aylık Fiyat             0.247890     1.000000     0.651174
# Total Ödeme             0.826172     0.651174     1.000000

# %%
import seaborn as sns 
sns.heatmap(Telecom_customer.corr())
# Out:
# <AxesSubplot:>

# %%
Telecom_customer.isnull().sum()
# Out:
# Cinsiyet            0
# Yaşlı               0
# Ortaklık            0
# Bağlılık            0
# Kiralama süresi     0
# Telefon Servisi     0
# Çoklu Hat           0
# İnternet Servisi    0
# Online Güvenlik     0
# Online Yedekleme    0
# Cihaz Koruması      0
# Teknik Destek       0
# TV yayını           0
# Film yayını         0
# Sözleşme            0
# E-fatura            0
# Ödeme               0
# Aylık Fiyat         0
# Total Ödeme         0
# Ayrılma             0
# dtype: int64

# %%
Kategorik = Telecom_customer.select_dtypes(include='object').drop('Ayrılma', axis=1).columns.tolist()
Sayısal =Telecom_customer.select_dtypes(exclude='object').columns.tolist()

# %%
for c in Kategorik:
    print('Column {} unique values: {}'.format(c, len(Telecom_customer[c].unique())))
# Out:
# Column Cinsiyet unique values: 2
# Column Yaşlı unique values: 2
# Column Ortaklık unique values: 2
# Column Bağlılık unique values: 2
# Column Telefon Servisi unique values: 2
# Column Çoklu Hat unique values: 2
# Column İnternet Servisi unique values: 3
# Column Online Güvenlik unique values: 2
# Column Online Yedekleme unique values: 2
# Column Cihaz Koruması unique values: 2
# Column Teknik Destek unique values: 2
# Column TV yayını  unique values: 2
# Column Film yayını unique values: 2
# Column Sözleşme unique values: 3
# Column E-fatura unique values: 2
# Column Ödeme unique values: 4

# %%
plt.figure(figsize=(18,18))
for i,c in enumerate(Kategorik):
    plt.subplot(5,4,i+1)
    sns.countplot(Telecom_customer[c], hue=Telecom_customer['Ayrılma'])
    plt.title(c)
    plt.xlabel('')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
Telecom_customer.head(8000)
# Out:
#      Cinsiyet  Yaşlı Ortaklık Bağlılık  Kiralama süresi Telefon Servisi  \
# 0      Female  Hayır     Evet    Hayır                1           Hayır
# 1        Male  Hayır    Hayır    Hayır               34            Evet
# 2        Male  Hayır    Hayır    Hayır                2            Evet
# 3        Male  Hayır    Hayır    Hayır               45           Hayır
# 4      Female  Hayır    Hayır    Hayır                2            Evet
# ...       ...    ...      ...      ...              ...             ...
# 7038     Male  Hayır     Evet     Evet               24            Evet
# 7039   Female  Hayır     Evet     Evet               72            Evet
# 7040   Female  Hayır     Evet     Evet               11           Hayır
# 7041     Male   Evet     Evet    Hayır                4            Evet
# 7042     Male  Hayır    Hayır    Hayır               66            Evet
#
#      Çoklu Hat İnternet Servisi Online Güvenlik Online Yedekleme  \
# ...

# %%
Telecom_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cinsiyet          7043 non-null   object
#  1   Yaşlı             7043 non-null   object
#  2   Ortaklık          7043 non-null   object
#  3   Bağlılık          7043 non-null   object
#  4   Kiralama süresi   7043 non-null   int64
#  5   Telefon Servisi   7043 non-null   object
#  6   Çoklu Hat         7043 non-null   object
#  7   İnternet Servisi  7043 non-null   object
#  8   Online Güvenlik   7043 non-null   object
#  9   Online Yedekleme  7043 non-null   object
#  10  Cihaz Koruması    7043 non-null   object
#  11  Teknik Destek     7043 non-null   object
#  12  TV yayını         7043 non-null   object
#  13  Film yayını       7043 non-null   object
#  14  Sözleşme          7043 non-null   object
#  15  E-fatura          7043 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoded = Telecom_customer.apply(lambda x: LabelEncoder().fit_transform(x) if x.dtype == 'object' else x)
encoded.head(8000)
# Out:
#       Cinsiyet  Yaşlı  Ortaklık  Bağlılık  Kiralama süresi  Telefon Servisi  \
# 0            0      1         0         1                1                1
# 1            1      1         1         1               34                0
# 2            1      1         1         1                2                0
# 3            1      1         1         1               45                1
# 4            0      1         1         1                2                0
# ...        ...    ...       ...       ...              ...              ...
# 7038         1      1         0         0               24                0
# 7039         0      1         0         0               72                0
# 7040         0      1         0         0               11                1
# 7041         1      0         0         1                4                0
# 7042         1      1         1         1               66                0
#
# ...

# %%
Ayrılma_oldu=encoded.loc[encoded['Ayrılma'].abs()>0]
Ayrılma_oldu
# Out:
#       Cinsiyet  Yaşlı  Ortaklık  Bağlılık  Kiralama süresi  Telefon Servisi  \
# 0            0      1         0         1                1                1
# 1            1      1         1         1               34                0
# 3            1      1         1         1               45                1
# 6            1      1         1         0               22                0
# 7            0      1         1         1               10                1
# ...        ...    ...       ...       ...              ...              ...
# 7037         0      1         1         1               72                0
# 7038         1      1         0         0               24                0
# 7039         0      1         0         0               72                0
# 7040         0      1         0         0               11                1
# 7042         1      1         1         1               66                0
#
# ...

# %%
Q1 = Ayrılma_oldu['Total Ödeme'].quantile(0.25)
Q3 = Ayrılma_oldu['Total Ödeme'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 3689.9499999999994

# %%
Q=Q3+(1.5*IQR)
Q
# Out:
# 9797.774999999998

# %%
encoded.drop(encoded[~((encoded['Total Ödeme'] < (Q3 + 1.5 * IQR)))&(encoded['Ayrılma']>0)].index, inplace=True)
encoded.head(8000)
# Out:
#       Cinsiyet  Yaşlı  Ortaklık  Bağlılık  Kiralama süresi  Telefon Servisi  \
# 0            0      1         0         1                1                1
# 1            1      1         1         1               34                0
# 2            1      1         1         1                2                0
# 3            1      1         1         1               45                1
# 4            0      1         1         1                2                0
# ...        ...    ...       ...       ...              ...              ...
# 7038         1      1         0         0               24                0
# 7039         0      1         0         0               72                0
# 7040         0      1         0         0               11                1
# 7041         1      0         0         1                4                0
# 7042         1      1         1         1               66                0
#
# ...

# %%
x = Telecom_customer.drop('Ayrılma', axis = 1)              
y = Telecom_customer['Ayrılma']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.85, random_state = 400)

# %%
x_test.head(8000)
# Out:
#      Cinsiyet  Yaşlı Ortaklık Bağlılık  Kiralama süresi Telefon Servisi  \
# 1076   Female  Hayır     Evet     Evet               58            Evet
# 2395   Female   Evet     Evet    Hayır               31            Evet
# 1969   Female  Hayır    Hayır    Hayır               60           Hayır
# 2697   Female  Hayır     Evet    Hayır               71            Evet
# 1108   Female  Hayır    Hayır    Hayır               69            Evet
# ...       ...    ...      ...      ...              ...             ...
# 1473   Female  Hayır    Hayır    Hayır               24            Evet
# 2578   Female   Evet     Evet     Evet               31            Evet
# 6716   Female  Hayır     Evet    Hayır                3            Evet
# 2585   Female  Hayır    Hayır    Hayır               37            Evet
# 6628   Female  Hayır    Hayır    Hayır                7            Evet
#
#      Çoklu Hat İnternet Servisi Online Güvenlik Online Yedekleme  \
# ...

# %%
x_train.head(8000)
# Out:
#      Cinsiyet  Yaşlı Ortaklık Bağlılık  Kiralama süresi Telefon Servisi  \
# 2755     Male  Hayır     Evet    Hayır               46            Evet
# 5983   Female  Hayır    Hayır    Hayır               22           Hayır
# 71     Female  Hayır     Evet     Evet               52            Evet
# 6366   Female  Hayır     Evet    Hayır               64            Evet
# 2776     Male   Evet     Evet    Hayır               16            Evet
# ...       ...    ...      ...      ...              ...             ...
# 140    Female   Evet     Evet     Evet               72            Evet
# 5049   Female  Hayır    Hayır    Hayır                1            Evet
# 2366   Female   Evet    Hayır    Hayır                1            Evet
# 3535     Male  Hayır     Evet     Evet               64            Evet
# 4444   Female  Hayır    Hayır    Hayır                3            Evet
#
#      Çoklu Hat İnternet Servisi Online Güvenlik Online Yedekleme  \
# ...

# %%
y_test.head(8000)
# Out:
# 1076    Ayrılma olmadı
# 2395    Ayrılma olmadı
# 1969    Ayrılma olmadı
# 2697    Ayrılma olmadı
# 1108    Ayrılma olmadı
#              ...
# 1473    Ayrıkma olmadı
# 2578    Ayrıkma olmadı
# 6716    Ayrıkma olmadı
# 2585    Ayrılma olmadı
# 6628    Ayrılma olmadı
# Name: Ayrılma, Length: 5987, dtype: object

# %%
y_train.head(8000)
# Out:
# 2755    Ayrılma olmadı
# 5983    Ayrılma olmadı
# 71      Ayrılma olmadı
# 6366    Ayrılma olmadı
# 2776    Ayrıkma olmadı
#              ...
# 140     Ayrılma olmadı
# 5049    Ayrıkma olmadı
# 2366    Ayrıkma olmadı
# 3535    Ayrılma olmadı
# 4444    Ayrıkma olmadı
# Name: Ayrılma, Length: 1056, dtype: object

# %%
x=encoded['Cinsiyet']
y=encoded['Ayrılma']
print('Cinsiyet:', x.corr(y)*100)
x=encoded['Yaşlı']
y=encoded['Ayrılma']
print('Yaşlı:', x.corr(y)*100)
x=encoded['Ortaklık']
y=encoded['Ayrılma']
print('Ortaklık:', x.corr(y)*100)
x=encoded['Bağlılık']
y=encoded['Ayrılma']
print('Bağlılık:', x.corr(y)*100)
x=encoded['Kiralama süresi']
y=encoded['Ayrılma']
print(' Kiralama Süresi:', x.corr(y)*100)
x=encoded['Telefon Servisi']
y=encoded['Ayrılma']
print('Telefon Servisi:', x.corr(y)*100)
x=encoded['Çoklu Hat']
y=encoded['Ayrılma']
print('Çoklu Hat:', x.corr(y)*100)
x=encoded['İnternet Servisi']
y=encoded['Ayrılma']
print('İnternet Servisi:', x.corr(y)*100)
x=encoded['Online Güvenlik']
y=encoded['Ayrılma']
print('Online Güvenlik:', x.corr(y)*100)
x=encoded['Online Yedekleme']
y=encoded['Ayrılma']
print('Online Yedekleme:', x.corr(y)*100)
x=encoded['Cihaz Koruması']
y=encoded['Ayrılma']
print('Cihaz Koruması:', x.corr(y)*100)
x=encoded['Teknik Destek']
y=encoded['Ayrılma']
print('Teknik Destek:', x.corr(y)*100)
x=encoded['Film yayını']
y=encoded['Ayrılma']
print('Film yayını:', x.corr(y)*100)
x=encoded['Sözleşme']
y=encoded['Ayrılma']
print('Sözleşme :', x.corr(y)*100)
x=encoded['E-fatura']
y=encoded['Ayrılma']
print('E-fatura:', x.corr(y)*100)
x=encoded['Ödeme']
y=encoded['Ayrılma']
print('Ödeme:', x.corr(y)*100)
x=encoded['Aylık Fiyat']
y=encoded['Ayrılma']
print(' Aylık Fiyat:', x.corr(y)*100)
x=encoded['Total Ödeme']
y=encoded['Ayrılma']
print('Total Ödeme:', x.corr(y)*100)
# Out:
# Cinsiyet: 0.8612095078997927
# Yaşlı: 15.147679595566672
# Ortaklık: -15.044754495917607
# Bağlılık: -16.422140157972436
#  Kiralama Süresi: 35.22514970162764
# Telefon Servisi: 1.1941980029002903
# Çoklu Hat: 4.0102127699826084
# İnternet Servisi: 4.729138768314235
# Online Güvenlik: -17.122629194855275
# Online Yedekleme: -8.225486893814256
# Cihaz Koruması: -6.615979128028959
# Teknik Destek: -16.46735559015929
# Film yayını: 6.138154801518677
# Sözleşme : 39.6712629209845
# E-fatura: 19.182533166646877
# Ödeme: -10.706200587340334
#  Aylık Fiyat: -19.33564222378467
# Total Ödeme: 19.832426260399526

# %%
x=encoded.drop('Ayrılma',axis=1)
y=encoded['Ayrılma']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.85, random_state=43)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder

# %%
Logistic_Regression = LogisticRegression(C=0.5,tol=0.1,multi_class='multinomial',solver='newton-cg',penalty='l2',max_iter=100)
Logistic_Regression.fit(x_train, y_train)
# Out:
# LogisticRegression(C=0.5, multi_class='multinomial', solver='newton-cg',
#                    tol=0.1)

# %%
y_pred=Logistic_Regression.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

# %%
classification_report(y_true=y_test, y_pred=y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.64      0.55      0.59      1601\n           1       0.84      0.89      0.86      4386\n\n    accuracy                           0.79      5987\n   macro avg       0.74      0.72      0.73      5987\nweighted avg       0.79      0.79      0.79      5987\n'

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 79.48889260063471

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 876,  725],
#        [ 503, 3883]], dtype=int64)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
NBG = GaussianNB()
NBG.fit(x_train, y_train)
y_tahmin = NBG.predict(x_test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.85, random_state=42)
print("x_train: ", x_train.shape)
print("x_test: ", x_test.shape)
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
print("Navy Bayes :", accuracy_score(y_test, y_tahmin))
print("Confusion Matrix :", confusion_matrix(y_test, y_tahmin))
print("classification Report :", classification_report(y_test, y_tahmin))
# Out:
# x_train:  (1056, 19)
# x_test:  (5987, 19)
# y_train:  (1056,)
# y_test:  (5987,)
# Navy Bayes : 0.7429430432603975
# Confusion Matrix : [[1132  475]
#  [1064 3316]]
# classification Report :               precision    recall  f1-score   support
#
#            0       0.52      0.70      0.60      1607
#            1       0.87      0.76      0.81      4380
#
#     accuracy                           0.74      5987
#    macro avg       0.70      0.73      0.70      5987
# weighted avg       0.78      0.74      0.75      5987
